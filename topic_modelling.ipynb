# %%
# !pip install pyLDAvis -qq
# !pip install -qq -U gensim
# !pip install spacy -qq
# !pip install matplotlib -qq
# !pip install seaborn -qq
# !python -m spacy download en_core_web_md -qq

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import spacy
import pyLDAvis.gensim_models
pyLDAvis.enable_notebook()# Visualise inside a notebook
import en_core_web_md
from gensim.corpora.dictionary import Dictionary
from gensim.models import LdaMulticore
from gensim.models import CoherenceModel
# Out:
# C:\Users\Dell\miniconda3\lib\site-packages\gensim\matutils.py:22: DeprecationWarning: Please use `triu` from the `scipy.linalg` namespace, the `scipy.linalg.special_matrices` namespace is deprecated.
#   from scipy.linalg.special_matrices import triu

# %%
fake = pd.read_parquet("../data/training_fake_final.parquet")
fake.head()
# Out:
#                                                 text  label
# 0  Jacob Zuma and wife admitted to hospital after...  False
# 1  Apparently Bisi Olatilo and Bolu Akin-Olugbade...  False
# 2  @lyne_ian @Jeremy05749458 3 hours ago Pope Fra...  False
# 3  “We commend President Buhari for the swiftness...  False
# 4  So the hippo that was in Fourways has been sla...  False

# %%
# Our spaCy model:
nlp = en_core_web_md.load()

# Tags I want to remove from the text
removal= ['ADV','PRON','CCONJ','PUNCT','PART','DET','ADP','SPACE', 'NUM', 'SYM']
tokens = []

for summary in nlp.pipe(fake['text']):
   proj_tok = [token.lemma_.lower() for token in summary if token.pos_ not in removal 
               and not token.is_stop and token.is_alpha]
   tokens.append(proj_tok)

# Add tokens to new column
fake['tokens'] = tokens
fake['tokens']
# Out:
# 0         [jacob, zuma, wife, admit, hospital, contract]
# 1      [bisi, olatilo, bolu, akin, olugbade, dead, re...
# 2      [hour, pope, francis, jorge, bergoglio, arrest...
# 3      [commend, president, buhari, swiftness, effici...
# 4                     [hippo, fourway, slaughter, crazy]
#                              ...
# 454    [brief, statement, utterance, president, uhuru...
# 455    [namibian, president, hage, g, geingob, confir...
# 456    [russia, target, african, countries, missile, ...
# 457    [breaking, vladamir, putin, issue, statement, ...
# 458    [photo, brave, little, woman, year, ukrainian,...
# Name: tokens, Length: 459, dtype: object

# %%
dictionary = Dictionary(fake['tokens'])
print(dictionary.token2id)
# Out:
# {'admit': 0, 'contract': 1, 'hospital': 2, 'jacob': 3, 'wife': 4, 'zuma': 5, 'akin': 6, 'bisi': 7, 'bolu': 8, 'careful': 9, 'dead': 10, 'olatilo': 11, 'olugbade': 12, 'relate': 13, 'arrest': 14, 'bergoglio': 15, 'chit': 16, 'count': 17, 'drug': 18, 'felony': 19, 'francis': 20, 'fraud': 21, 'holy': 22, 'hour': 23, 'human': 24, 'incest': 25, 'indictment': 26, 'jorge': 27, 'paraphernalia': 28, 'pope': 29, 'porn': 30, 'possession': 31, 'trafficking': 32, 'abduct': 33, 'abductor': 34, 'buhari': 35, 'commend': 36, 'difference': 37, 'efficiency': 38, 'eu': 39, 'forum': 40, 'lad': 41, 'occur': 42, 'president': 43, 'rescue': 44, 'rights': 45, 'school': 46, 'schoolgirl': 
man': 221, 'act': 222, 'birth': 223, 'compulsory': 224, 'country': 225, 'dna': 226, 'pass': 227, 'paternity': 228, 'test': 229, 'zimbabwe': 230, 'airport': 231, 'dollar': 232, 'lesotho': 233, 'new': 234, 'approve': 235, 'bheki': 236, 'budget': 237, 'cabinet': 238, 'cele': 239, 'citizen': 240, 'concerned': 241, 'crime': 242, 'cut': 243, 'fighting': 244, 'general': 245, 'ordinary': 246, 'police': 247, 'protection': 248, 'safety': 249, 'say': 250, 'up': 251, 'vip': 252, 'amandla': 253, 'city': 254, 'durban': 255, 'freejacobzuma': 256, 'call': 257, 'get': 258, 'home': 259, 'interesting': 260, 'jacobzuma': 261, 'join': 262, 'julius': 263, 'kid': 264, 'malema': 265, 'prison': 266, 'sandf': 267, 'thing': 268, 'thug': 269, 'zumaunrest': 270, 'g ...

# %%
# Filter dictionary
dictionary.filter_extremes(no_below=5, no_above=0.5, keep_n=2000)

# Create corpus
corpus = [dictionary.doc2bow(doc) for doc in fake['tokens']]

# %%
lda_model5 = LdaMulticore(corpus=corpus, id2word=dictionary, iterations=100, num_topics=5, workers = 4, passes=100)
lda_model9 = LdaMulticore(corpus=corpus, id2word=dictionary, iterations=100, num_topics=9, workers = 4, passes=100)

# %%
lda_display = pyLDAvis.gensim_models.prepare(lda_model5, corpus, dictionary)
pyLDAvis.display(lda_display)
# Out:
# C:\Users\Dell\miniconda3\lib\site-packages\pyLDAvis\_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   default_term_info = default_term_info.sort_values(
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el50425785717201762443073374"></div>
# <script type="text/javascript">
#
# var ldavis_el50425785717201762443073374_data = {"mdsDat": {"x": [-0.2874554440669294, 0.08203661987082239, 0.05602925974397739, 0.06404931279480873, 0.0853402516573211], "y": [0.006070913078790909, -0.12152080054339548, -0.025168040186983216, -0.052794762615055904, 0.19341269026664365], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [35.548875047448476, 19.879016376910048, 15.902674658032847, 15.085020650348794, 13.58441326725984]}, "tinfo": {"Term": ["africa", "south", "child", "food", "price", "water", "nigeria", "increase", "ruto", "president", "drink", "man", "school", "african", "leave", "kenya", "woman", "blood", "ginger", "morning", "party", "pain", "cost", "sa", "world", "people", "know", "state", "eat", "buhari", "drink", "ginger", "pain", "pressure", "lemon", "remedy", "ingredient", "mix", "preparation", "garlic", "boil", "glass", "juice", "herbal", "morning", "natural", "ulcer", "liver", "prepare", "powder", "leaf", "eat", "add", "pot", "seed", "treatment", "face", "cup", "bark", "pineapple", "water", "blood", "tea", "leave", "body", "small", "woman", "day", "cause", "problem", "good", "cancer", "high", "school", "buhari", "ukraine", "igbo", "corona", "officer", "covid", "child", "virus", "past", "human", "hiv", "resident", "mean", "force", "hospital", "young", "vaccine", "leadership", "aid", "collect", "medium", "offer", "mind", "orlu", "ensure", "dr", "leader", "national", "nigerians", "nigeria", "die", "new", "year", "disease", "death", "live", "president", "people", "state", "day", "nigerian", "government", "cause", "world", "say", "know", "go", "country", "come", "price", "cost", "china", "poor", "demand", "pray", "target", "food", "believe", "company", "user", "dead", "quote", "fuel", "hand", "kisumu", "send", "dp", "war", "produce", "miss", "global", "message", "bbi", "contact", "watch", "land", "increase", "show", "click", "breaking", "fact", "breast", "check", "toxin", "come", "community", "information", "cancer", "south", "go", "apply", "read", "year", "say", "want", "sa", "africa", "child", "party", "mask", "win", "attend", "soldier", "odm", "girl", "russian", "federal", "candidate", "place", "political", "wear", "sign", "partner", "comment", "spend", "fund", "yesterday", "court", "deal", "student", "moment", "true", "election", "minister", "united", "join", "support", "act", "card", "think", "kill", "order", "look", "thing", "state", "start", "people", "apply", "money", "news", "let", "government", "nigeria", "know", "today", "tell", "life", "say", "come", "country", "time", "rape", "uhuru", "kenyans", "county", "road", "william", "protest", "illegal", "ruto", "kenya", "nairobi", "rate", "city", "fake", "south", "africa", "declare", "man", "african", "anc", "governor", "real", "deputy", "service", "sa", "odinga", "protect", "raila", "burn", "usa", "world", "president", "country", "accord", "woman", "know", "news", "high", "black", "people", "say", "leave", "time"], "Freq": [60.0, 52.0, 56.0, 43.0, 35.0, 66.0, 51.0, 38.0, 25.0, 52.0, 43.0, 32.0, 23.0, 27.0, 57.0, 20.0, 55.0, 45.0, 32.0, 37.0, 15.0, 31.0, 15.0, 20.0, 27.0, 60.0, 45.0, 31.0, 34.0, 16.0, 42.43408156070792, 31.873548163152947, 30.913767978530956, 26.113419841839836, 26.113094811904393, 25.152337164994798, 23.232503960403545, 21.312756165138396, 21.31265414844333, 20.352461152078515, 19.392773494226464, 19.392699947306767, 19.391584881104887, 17.472514429245347, 35.66832959898782, 15.544566152433811, 14.592714800251578, 14.592020849477002, 13.632438767041942, 13.632282183277422, 12.672149685185262, 32.483940147025145, 27.063643671863577, 11.712102596419204, 11.711993462280295, 26.120157688676734, 11.702534379414553, 24.19738972474138, 10.752302245706327, 10.752189552845499, 61.70929149003692, 42.2091276306442, 18.435884178044883, 48.81551527978397, 30.265375961987424, 15.532898289495831, 30.891620865776577, 27.922363271375946, 24.577926232224144, 17.610847881513802, 20.989453396068775, 18.080312104837212, 17.476113483348016, 22 ...

# %%
#Optimal Number of Topics using Coherence Score:

# Coherence score using C_v:
topics = []
score = []
for i in range(1,20,1):
   lda_model = LdaMulticore(corpus=corpus, id2word=dictionary, iterations=10, num_topics=i, workers = 4, passes=10, random_state=100)
   cm = CoherenceModel(model=lda_model, texts = fake['tokens'], corpus=corpus, dictionary=dictionary, coherence='c_v')
   topics.append(i)
   score.append(cm.get_coherence())
_=plt.plot(topics, score)
_=plt.xlabel('Number of Topics')
_=plt.ylabel('Coherence Score')
plt.show()

# %%
lda_display = pyLDAvis.gensim_models.prepare(lda_model9, corpus, dictionary)
pyLDAvis.display(lda_display)
# Out:
# C:\Users\Dell\miniconda3\lib\site-packages\pyLDAvis\_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   default_term_info = default_term_info.sort_values(
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el5042578573279520898319870"></div>
# <script type="text/javascript">
#
# var ldavis_el5042578573279520898319870_data = {"mdsDat": {"x": [0.2910698077299583, 0.004251137076505058, 0.06887725974196329, -0.038304738672656144, -0.04601401882360817, 0.08745587296224337, -0.13945449231714385, -0.14576328787437734, -0.08211753982288447], "y": [-0.13523398345906618, 0.16214612684058713, 0.031096746029453847, 0.1404346736859643, 0.05690543078037528, 0.0739505520234301, -0.07830690111545527, -0.10260809262942013, -0.1483845521558687], "topics": [1, 2, 3, 4, 5, 6, 7, 8, 9], "cluster": [1, 1, 1, 1, 1, 1, 1, 1, 1], "Freq":